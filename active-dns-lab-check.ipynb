# %%
from __future__ import division
import numpy as np
import os, sys
import matplotlib
#matplotlib.use('Agg')
# %matplotlib nbagg
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict

# %%
smartthings_bg = pd.read_csv('data/dns-background/smartthings_alone_20160702_4hr.csv', sep='|')
smartthings_bg[ smartthings_bg['ip.src']=='10.42.0.89' ]
# Out:
#      frame.time_relative      ip.src                dns.qry.name
# 13              2.337858  10.42.0.89                pool.ntp.org
# 14              2.343969  10.42.0.89  DC.connect.smartthings.com
# 15              2.928047  10.42.0.89  DC.connect.smartthings.com
# 28             17.970738  10.42.0.89                pool.ntp.org
# 29             18.020785  10.42.0.89  DC.connect.smartthings.com
# 53            120.121931  10.42.0.89                pool.ntp.org
# 54            120.163391  10.42.0.89  DC.connect.smartthings.com
# 72            718.927538  10.42.0.89                pool.ntp.org
# 75           1317.759216  10.42.0.89                pool.ntp.org
# 76           1916.596260  10.42.0.89                pool.ntp.org
# 79           2515.424847  10.42.0.89                pool.ntp.org
# 80           3114.242156  10.42.0.89                pool.ntp.org
# 81           3713.074114  10.42.0.89                pool.ntp.org
# ...

# %%
echo_bg = pd.read_csv('data/dns-background/echo_bg_1day.csv', sep='|')
echo_bg[echo_bg['ip.src']=='10.0.0.4']
# Out:
#       frame.time_relative    ip.src  \
# 0               80.590272  10.0.0.4
# 1               80.683124  10.0.0.4
# 2               80.683437  10.0.0.4
# 3               80.683496  10.0.0.4
# 4               80.886887  10.0.0.4
# 5               80.886961  10.0.0.4
# 6               81.153794  10.0.0.4
# 7               81.153855  10.0.0.4
# 8               81.355916  10.0.0.4
# 10              81.364727  10.0.0.4
# 11              81.370364  10.0.0.4
# 12              81.386735  10.0.0.4
# 13              81.423489  10.0.0.4
# 14              81.449025  10.0.0.4
# 15              81.536817  10.0.0.4
# 16              81.610323  10.0.0.4
# 17              81.736042  10.0.0.4
# 18              94.434385  10.0.0.4
# 19              94.434510  10.0.0.4
# 20              94.452078  10.0.0.4
# 21              94.452219  10.0.0.4
# 22              94.487988  10.0.0.4
# 23              94.488113  10.0.0.4
# 24              94.743350  10.0.0.4
# 26              94.749408  10.0.0.4
# ...

# %%
nest_bg = pd.read_csv('data/dns-background/nest_bg_2days.csv', sep='|')
nest_bg[nest_bg['ip.src']=='10.0.0.7']
# Out:
#       frame.time_relative    ip.src  \
# 0               16.015776  10.0.0.7
# 2               16.015901  10.0.0.7
# 3               16.017429  10.0.0.7
# 4               16.017807  10.0.0.7
# 6               16.017998  10.0.0.7
# 7               16.019476  10.0.0.7
# 10             246.102378  10.0.0.7
# 12             246.102542  10.0.0.7
# 13             246.102645  10.0.0.7
# 14             445.307780  10.0.0.7
# 16             445.307959  10.0.0.7
# 17             445.308176  10.0.0.7
# 18             445.342783  10.0.0.7
# 20             445.343595  10.0.0.7
# 21             445.344641  10.0.0.7
# 22             528.661947  10.0.0.7
# 24             528.662126  10.0.0.7
# 25             528.662222  10.0.0.7
# 28             783.662075  10.0.0.7
# 30             783.662233  10.0.0.7
# 31             783.662523  10.0.0.7
# 32            1366.964025  10.0.0.7
# 34            1366.964756  10.0.0.7
# 35            1366.965139  10.0.0.7
# 38            2192.664538  10.0.0.7
# ...

# %%
dropcam_sharx_bg = pd.read_csv('data/dns-background/nestcam_sharxcam_20160702_24hr.csv', sep='|')
dropcam_sharx_bg[dropcam_sharx_bg['ip.src']=='10.0.0.9']
# Out:
#         frame.time_relative    ip.src       dns.qry.name
# 0                  3.748894  10.0.0.9  nexus.dropcam.com
# 2                  3.752057  10.0.0.9  nexus.dropcam.com
# 4                  3.839127  10.0.0.9       pool.ntp.org
# 6                  3.839238  10.0.0.9       pool.ntp.org
# 8                  3.843355  10.0.0.9       pool.ntp.org
# 9                  3.843492  10.0.0.9       pool.ntp.org
# 10                 6.755462  10.0.0.9  nexus.dropcam.com
# 12                 6.851469  10.0.0.9       pool.ntp.org
# 13                 6.853163  10.0.0.9       pool.ntp.org
# 18                12.761721  10.0.0.9  nexus.dropcam.com
# 20                12.765565  10.0.0.9  nexus.dropcam.com
# 22                12.845300  10.0.0.9       pool.ntp.org
# 24                12.845474  10.0.0.9       pool.ntp.org
# 26                12.850587  10.0.0.9       pool.ntp.org
# 27                12.852720  10.0.0.9       pool.ntp.org
# ...

# %%
dropcam_sharx_bg[dropcam_sharx_bg['ip.src']=='10.0.0.8']
# Out:
#         frame.time_relative    ip.src  \
# 14                 8.928878  10.0.0.8
# 16                 8.950104  10.0.0.8
# 32                18.968684  10.0.0.8
# 34                18.980811  10.0.0.8
# 50                25.034497  10.0.0.8
# 52                25.069569  10.0.0.8
# 54                25.876959  10.0.0.8
# 56                25.903401  10.0.0.8
# 58                28.999188  10.0.0.8
# 60                29.024662  10.0.0.8
# 76                35.088296  10.0.0.8
# 78                35.130789  10.0.0.8
# 80                35.921008  10.0.0.8
# 82                35.960051  10.0.0.8
# 84                40.054669  10.0.0.8
# 86                40.091648  10.0.0.8
# 88                45.148712  10.0.0.8
# 90                45.154349  10.0.0.8
# 92                45.980516  10.0.0.8
# 94                45.999087  10.0.0.8
# 96                50.108873  10.0.0.8
# 98                50.129680  10.0.0.8
# 114               56.227265  10.0.0.8
# ...
